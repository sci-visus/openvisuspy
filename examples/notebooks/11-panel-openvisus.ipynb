# %%
import os,sys,logging
import numpy as np
import pandas as pd

import panel as pn
pn.extension()

from openvisuspy import Slice,Slices

url=f"http://atlantis.sci.utah.edu/mod_visus?dataset=david_subsampled&cached=1"   
view=Slice(show_options=["palette","timestep","field","direction","offset"], disable_timers=True) 
view.setDataset(url)   
view.setDirection(2)
view.setPalette("Greys256")
view.setPaletteRange((0,255))
view.setTimestep(view.getTimestep())
view.setField(view.getField())  

text_input = pn.widgets.TextInput(name='Text Input', placeholder='Enter a string here...')
text_input.value=""   

timer_count=0
def OnTimer(): 
    global timer_count,slice,text_input
    timer_count+=1
    # if I don't do this,  Panel/bokeh/timers will not work (INCREDIBLE!)
    text_input.value=str(timer_count)   
    view.onIdle() # this is needed for all events

cb=pn.state.add_periodic_callback(OnTimer, 10) 
pn.Column(text_input,view.layout)
# Out:
# <style>.bk-root, .bk-root .bk:before, .bk-root .bk:after {
#   font-family: var(--jp-ui-font-size1);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--jp-ui-font-color1);
# }
# </style>
# VISUS_BACKEND=cpp
# Column
#     [0] TextInput(name='Text Input', placeholder='Enter a string here...')
#     [1] Bokeh(Column)
