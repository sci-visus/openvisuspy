# %% [markdown]
# # Import OpenVisus

# %%
import os,sys,logging,time
import asyncio
import numpy as np
import pandas as pd

import panel as pn
pn.extension()

from openvisuspy import Slice,Slices
# Out:
# <style>.bk-root, .bk-root .bk:before, .bk-root .bk:after {
#   font-family: var(--jp-ui-font-size1);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--jp-ui-font-color1);
# }
# </style>
# # VISUS_BACKEND=py

# %% [markdown]
# # Single slice

# %%
url=f"http://atlantis.sci.utah.edu/mod_visus?dataset=david_subsampled&cached=1" 

view=Slice(show_options=["palette","timestep","field","direction","offset"]) 
view.setDataset(url)   
view.setDirection(2)
view.setPalette("Greys256")
view.setPaletteRange((0,255))
view.setTimestep(view.getTimestep())
view.setField(view.getField()) 

# MAY NEED TO EXECUTE TWICE if you don't get anything or the timer is not working 
app=view.getLayout(doc=None,
                   is_panel=True, # IMPORTANT
                   is_notebook=True , # IMPORTANT
                  )
app
# Out:
# Bokeh(Column)

# %% [markdown]
# # Multiple slices

# %%
view=Slices(show_options=["palette","timestep","field","direction","offset"],num_views=2) 
view.setDataset(url)   
view.setDirection(2)
view.setPalette("Greys256")
view.setPaletteRange((0,255))
view.setTimestep(view.getTimestep())
view.setField(view.getField())

# MAY NEED TO EXECUTE TWICE if you don't get anything or the timer is not working 
app=view.getLayout(doc=None,is_panel=True,is_notebook=True)
app
# Out:
# Bokeh(Column)
